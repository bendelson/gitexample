# %% [markdown]
# # Pandas basics

# %%
#Pandas Ordner im Verhältnis zu den anderen Dateien?
# !ls
# Out:
# 01-pandas basics.ipynb continent_facts.csv    countries.csv

# %%
#Wo liegt der ganze Bumms denn?
# !pwd
# Out:
# /Users/mendelson/Downloads/06-classwork

# %%
#Wir installieren pandas mit Prozent vorne, hat noch seltener Probleme, aber ! geht auch
# !pip install --quiet pandas

# %%
#--quiet ich will ich sehen, was da alles einzeln runtergeladen wird. 
#--quiet
#--verbose, das Gegenstück dazu, wenn du noch mehr Details willst. (-q und -v gehen auch)
#verbose brauchste nur, wenn etwas failed bei der Installation.
# --help ist in der Commandline, um Befehle angezeigt zu bekommen.
# Out:
# Type help() for interactive help, or help(object) for help about object.

# %%
#Top 10 most common pip commands
#was tipp ich, um zu sagen, dass ich requests nutzen will?
import requests

# %%
import pandas as pd
#Wenn etwas nicht weiter ausgeführt wird, nochmal Restart machen!)

# %%
#Saving data to a variable makes sense (and this is a dataframe)
#this is called a dataframe
#wer pandas as pd importiert will auch df benutzen als dataframe abkürzung
df=pd.read_csv("countries.csv")

# %%
df
# Out:
#                  country   continent  life_expectancy  population  \
# 0            Afghanistan        Asia           54.863    22856302
# 1                Albania      Europe           74.200     3071856
# 2                Algeria      Africa           68.963    30533827
# 3                 Angola      Africa           45.234    13926373
# 4    Antigua and Barbuda  N. America           73.544       77656
# ..                   ...         ...              ...         ...
# 183              Vietnam        Asia           73.777    78758010
# 184   West Bank and Gaza        Asia           70.929     3198560
# 185          Yemen, Rep.        Asia           60.404    17723186
# 186               Zambia      Africa           41.802    10201562
# 187             Zimbabwe      Africa           43.976    12509477
#
#               gdp
# 0     15153728226
# 1     12886435920
# 2    155661450046
# 3     34063908358
# 4       989182128
# ..            ...
# 183  124201381770
# ...

# %%
#Was macht man, wenn man zwei DataFrames hat? 
# #Meist kombiniert man beide zu einem gemeinsamen.
#Sonst: Wer zuerst kommt, ist df, der andere bekommt einen anderen Namen.
#df.drop_duplicates(subset=['col1', 'col2'])

# %%
#Erste 5 Zeilen der File
df.head()
# Out:
#                country   continent  life_expectancy  population           gdp
# 0          Afghanistan        Asia           54.863    22856302   15153728226
# 1              Albania      Europe           74.200     3071856   12886435920
# 2              Algeria      Africa           68.963    30533827  155661450046
# 3               Angola      Africa           45.234    13926373   34063908358
# 4  Antigua and Barbuda  N. America           73.544       77656     989182128

# %%
#Wenn wir Dataframe verändern, saved er NICHT die csv neu, ist alles erstmal nur im Python-Code.

# %%
#Show me the last five rows
df.tail()
# Out:
#                 country continent  life_expectancy  population           gdp
# 183             Vietnam      Asia           73.777    78758010  124201381770
# 184  West Bank and Gaza      Asia           70.929     3198560   24264276160
# 185         Yemen, Rep.      Asia           60.404    17723186   39292303362
# 186              Zambia    Africa           41.802    10201562   10558616670
# 187            Zimbabwe    Africa           43.976    12509477    9319560365

# %%
df.head()
# Out:
#                country   continent  life_expectancy  population           gdp
# 0          Afghanistan        Asia           54.863    22856302   15153728226
# 1              Albania      Europe           74.200     3071856   12886435920
# 2              Algeria      Africa           68.963    30533827  155661450046
# 3               Angola      Africa           45.234    13926373   34063908358
# 4  Antigua and Barbuda  N. America           73.544       77656     989182128

# %%
#bound method als Antwort der Maschine: Dann hast du wohl die Klammern vergessen!
#Documentation von etwas kannst du machen, wenn du shift drücks und dann tab dazu.
df.tail()
# Out:
#                 country continent  life_expectancy  population           gdp
# 183             Vietnam      Asia           73.777    78758010  124201381770
# 184  West Bank and Gaza      Asia           70.929     3198560   24264276160
# 185         Yemen, Rep.      Asia           60.404    17723186   39292303362
# 186              Zambia    Africa           41.802    10201562   10558616670
# 187            Zimbabwe    Africa           43.976    12509477    9319560365

# %%
#Hier kannst du jetzt alle Lebenserwartungen ausspucken lassen
df['life_expectancy']
#oben ist schön, unten eher nicht so, findet soma. Nur eine Series, weil es nur um eine Column geht.
# Out:
# 0      54.863
# 1      74.200
# 2      68.963
# 3      45.234
# 4      73.544
#         ...
# 183    73.777
# 184    70.929
# 185    60.404
# 186    41.802
# 187    43.976
# Name: life_expectancy, Length: 188, dtype: float64

# %%
#"You know everything about Pandas in your heart"
# .rank (Position von etwas ausspucken)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#display. max_columns.
#Es gibt Autocomplete! Einfach Tab benutzen!
#df.population oder df['population']

# %%
#hey pandas, give me a dataframe, give me the life expectancy column
df['life_expectancy']
# Out:
# 0      54.863
# 1      74.200
# 2      68.963
# 3      45.234
# 4      73.544
#         ...
# 183    73.777
# 184    70.929
# 185    60.404
# 186    41.802
# 187    43.976
# Name: life_expectancy, Length: 188, dtype: float64

# %%
df
# Out:
#                  country   continent  life_expectancy  population  \
# 0            Afghanistan        Asia           54.863    22856302
# 1                Albania      Europe           74.200     3071856
# 2                Algeria      Africa           68.963    30533827
# 3                 Angola      Africa           45.234    13926373
# 4    Antigua and Barbuda  N. America           73.544       77656
# ..                   ...         ...              ...         ...
# 183              Vietnam        Asia           73.777    78758010
# 184   West Bank and Gaza        Asia           70.929     3198560
# 185          Yemen, Rep.        Asia           60.404    17723186
# 186               Zambia      Africa           41.802    10201562
# 187             Zimbabwe      Africa           43.976    12509477
#
#               gdp
# 0     15153728226
# 1     12886435920
# 2    155661450046
# 3     34063908358
# 4       989182128
# ..            ...
# 183  124201381770
# ...

# %%
#df.sort_values('life_expectancy', ascending=False) oder True, wenn du die absteigenden willst
df.sort_values('life_expectancy', ascending=False).head(30)
#mit .head(20) kann ich auch auswählen, dass nur die Spitze gezeigt wird und davon gleich mehrere Länder
#True und False immer groß schreiben
# Out:
#               country   continent  life_expectancy  population             gdp
# 83              Japan        Asia        81.350000   125720310   3590446333290
# 72   Hong Kong, China        Asia        80.361000     6783317    203309577124
# 161       Switzerland      Europe        79.990000     7167908    246475684488
# 7           Australia     Oceania        79.930000    19164351    560384787591
# 160            Sweden      Europe        79.840000     8860153    253754781920
# 81              Italy      Europe        79.730000    56986329   1547748695640
# 74            Iceland      Europe        79.720000      281210      8743381320
# 29             Canada  N. America        79.410000    30667365    995094659520
# 155             Spain      Europe        79.340000    40288457    943152778370
# 57             France      Europe        79.230000    59047795   1690892657620
# 121       New Zealand     Oceania        78.900000     3858032     84471610640
# ...

# %%
df[['country', 'life_expectancy']]
#Warum hier doppelte eckige Klammern? Weil ich zwei verschiedene Columns brauche?
#Pandas Cheat Sheet aufrufen
#numbers.sort sortiert permanently, während sorted(numbers) es nur so ändert.

#df.sort_values('life_expectancy', ascending=False).head(10)
#df.head(10).sort_values('life_expectancy', ascending=False)
#Das erste sortiert alle Values und gibt dir dann die Top 10, das andere nimmt die Top 10 und sortiert sie.
# Out:
#                  country  life_expectancy
# 0            Afghanistan           54.863
# 1                Albania           74.200
# 2                Algeria           68.963
# 3                 Angola           45.234
# 4    Antigua and Barbuda           73.544
# ..                   ...              ...
# 183              Vietnam           73.777
# 184   West Bank and Gaza           70.929
# 185          Yemen, Rep.           60.404
# 186               Zambia           41.802
# 187             Zimbabwe           43.976
#
# [188 rows x 2 columns]

# %%
#Wenn man nach dem Index abgreifen will, nicht nur in eckigen Klammern Namen eingeben, sondern:
df.loc[2]
#Gibt mir das dritte Land
# Out:
# country                 Algeria
# continent                Africa
# life_expectancy          68.963
# population             30533827
# gdp                155661450046
# Name: 2, dtype: object

# %%
#Nach Kontinenten filtern?
df['continent']=='Europe'
#So geht er durch jede Zeile und vergleicht die Rows mit dem eingegebenen Titel
#Noch nicht so hilreich
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 183    False
# 184    False
# 185    False
# 186    False
# 187    False
# Name: continent, Length: 188, dtype: bool

# %%
df[df['continent']=='Europe']
#Jetzt sind es nur noch die Länder aus diesem Kontinent, Gratulation!)
# Out:
#                     country continent  life_expectancy  population  \
# 1                   Albania    Europe        74.200000     3071856
# 6                   Armenia    Europe        71.494000     3076098
# 8                   Austria    Europe        78.330000     8004712
# 9                Azerbaijan    Europe        66.851000     8110723
# 14                  Belarus    Europe        68.990000    10057810
# 15                  Belgium    Europe        77.910000    10175684
# 20   Bosnia and Herzegovina    Europe        74.882000     3693698
# 24                 Bulgaria    Europe        71.590000     8006158
# 41                  Croatia    Europe        74.798000     4505533
# 43                   Cyprus    Europe        78.011000      943294
# 44               Czech Rep.    Europe        75.050000    10242890
# 45                  Denmark    Europe        76.900000     5339501
# 53                  Estonia    Europe        70.800000     1370749
# ...

# %%
(
    df.sort_values('life_expectancy', ascending=False)
    .head(10)
    [['country', 'life_expectancy']]
)
# Out:
#               country  life_expectancy
# 83              Japan           81.350
# 72   Hong Kong, China           80.361
# 161       Switzerland           79.990
# 7           Australia           79.930
# 160            Sweden           79.840
# 81              Italy           79.730
# 74            Iceland           79.720
# 29             Canada           79.410
# 155             Spain           79.340
# 57             France           79.230

# %%
df[df['life_expectancy']>80]
# Out:
#              country continent  life_expectancy  population            gdp
# 72  Hong Kong, China      Asia           80.361     6783317   203309577124
# 83             Japan      Asia           81.350   125720310  3590446333290

# %%
#Every country in Asia with expectancy over 70
#df['life_expectancy']>70
#df['continent']=='Asia'
#df[(df['life_expectancy']>70)&(df['continent']=='Asia')]
df[(df['life_expectancy']>70)&(df['continent']=='Asia')].sort_values('life_expectancy')
# Out:
#                   country continent  life_expectancy  population  \
# 172                Turkey      Asia           70.010    63627862
# 78                   Iraq      Asia           70.845    23857458
# 166              Thailand      Asia           70.921    63155029
# 184    West Bank and Gaza      Asia           70.929     3198560
# 156             Sri Lanka      Asia           71.078    18745084
# 84                 Jordan      Asia           71.724     4827096
# 34                  China      Asia           72.124  1269116737
# 126                  Oman      Asia           72.139     2264163
# 143          Saudi Arabia      Asia           72.401    20045276
# 104              Malaysia      Asia           72.810    23414909
# 90                 Kuwait      Asia           73.133     1940786
# 162                 Syria      Asia           73.316    15988534
# 183               Vietnam      Asia           73.777    78758010
# ...

# %%
#Immer mit Comparisons arbeiten: Dann eckige Klammern nochmal drum und den Gesamt-Dataframe am Anfang nennen
